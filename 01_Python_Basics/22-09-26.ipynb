# %%
x = 22 
print (x)

# %%
type(x)

# %%
y="mint"

print(y)

# %%
type(y)

# %%
y="ansh"

y="mint"
print(y)

# %%
x,y,z="mint","vanilla","chocolate"
print(x)
print(y)
print(z)

# %%
ice_cream = ["mint", "vanilla", "chocolate"]

x,y,z = ice_cream
print(x)
print(y)
print(z)

# %%
# camel case

#test variable case

testVariableCase = "test variable case"

# %%
#pascal case

#test variable case

TestVariableCase = "test variable case"

# %%
#snake case

#test variable case

test_variable_case = "test variable case"

# %%
x="ice cream is my favorite dessert"+"."
print(x)

# %%
y=2+4
print(y)

# %%
x="introduction to python"
y=x.title()
print(y)

# %%
y=2
x=3
z=1
print(x+y+z)

# %%
x="ice cream"
y=2
print(x,y)
